# %% [markdown]
# # ETL Pipeline Preparation
# Follow the instructions below to help you create your ETL pipeline.
# ### 1. Import libraries and load datasets.
# - Import Python libraries
# - Load `messages.csv` into a dataframe and inspect the first few lines.
# - Load `categories.csv` into a dataframe and inspect the first few lines.

# %%
# import libraries
import pandas as pd
from sqlalchemy import create_engine

# %%
# load messages dataset
messages = pd.read_csv("messages.csv")
messages.head()
# Out:
#    id                                            message  \
# 0   2  Weather update - a cold front from Cuba that c...
# 1   7            Is the Hurricane over or is it not over
# 2   8                    Looking for someone but no name
# 3   9  UN reports Leogane 80-90 destroyed. Only Hospi...
# 4  12  says: west side of Haiti, rest of the country ...
#
#                                             original   genre
# 0  Un front froid se retrouve sur Cuba ce matin. ...  direct
# 1                 Cyclone nan fini osinon li pa fini  direct
# 2  Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 3  UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 4  facade ouest d Haiti et le reste du pays aujou...  direct

# %%
messages = messages.set_index("id")

# %%
# load categories dataset
categories = pd.read_csv("categories.csv")
categories.head()
# Out:
#    id                                         categories
# 0   2  related-1;request-0;offer-0;aid_related-0;medi...
# 1   7  related-1;request-0;offer-0;aid_related-1;medi...
# 2   8  related-1;request-0;offer-0;aid_related-0;medi...
# 3   9  related-1;request-1;offer-0;aid_related-1;medi...
# 4  12  related-1;request-0;offer-0;aid_related-0;medi...

# %%
categories = categories.set_index("id")

# %%
categories.head()
# Out:
#                                            categories
# id
# 2   related-1;request-0;offer-0;aid_related-0;medi...
# 7   related-1;request-0;offer-0;aid_related-1;medi...
# 8   related-1;request-0;offer-0;aid_related-0;medi...
# 9   related-1;request-1;offer-0;aid_related-1;medi...
# 12  related-1;request-0;offer-0;aid_related-0;medi...

# %% [markdown]
# ### 2. Merge datasets.
# - Merge the messages and categories datasets using the common id
# - Assign this combined dataset to `df`, which will be cleaned in the following steps

# %%
# merge datasets
df = pd.DataFrame.join(self=messages, other=categories)
df.head()
# Out:
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
# 8                     Looking for someone but no name
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...
# 12  says: west side of Haiti, rest of the country ...
#
#                                              original   genre  \
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...  direct
# 7                  Cyclone nan fini osinon li pa fini  direct
# 8   Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 12  facade ouest d Haiti et le reste du pays aujou...  direct
#
#                                            categories
# id
# 2   related-1;request-0;offer-0;aid_related-0;medi...
# 7   related-1;request-0;offer-0;aid_related-1;medi...
# 8   related-1;request-0;offer-0;aid_related-0;medi...
# 9   related-1;request-1;offer-0;aid_related-1;medi...
# 12  related-1;request-0;offer-0;aid_related-0;medi...

# %% [markdown]
# ### 3. Split `categories` into separate category columns.
# - Split the values in the `categories` column on the `;` character so that each value becomes a separate column. You'll find [this method](https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.Series.str.split.html) very helpful! Make sure to set `expand=True`.
# - Use the first row of categories dataframe to create column names for the categories data.
# - Rename columns of `categories` with new column names.

# %%
# create a dataframe of the 36 individual category columns
categories = df["categories"].str.split(";", expand=True)
categories.head()
# Out:
#            0          1        2              3               4   \
# id
# 2   related-1  request-0  offer-0  aid_related-0  medical_help-0
# 7   related-1  request-0  offer-0  aid_related-1  medical_help-0
# 8   related-1  request-0  offer-0  aid_related-0  medical_help-0
# 9   related-1  request-1  offer-0  aid_related-1  medical_help-0
# 12  related-1  request-0  offer-0  aid_related-0  medical_help-0
#
#                     5                    6           7           8   \
# id
# 2   medical_products-0  search_and_rescue-0  security-0  military-0
# 7   medical_products-0  search_and_rescue-0  security-0  military-0
# 8   medical_products-0  search_and_rescue-0  security-0  military-0
# 9   medical_products-1  search_and_rescue-0  security-0  military-0
# 12  medical_products-0  search_and_rescue-0  security-0  military-0
#
#                9        ...                    26                      27  \
# id                      ...
# 2   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 7   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 8   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 9   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 12  child_alone-0       ...         aid_centers-0  other_infrastructure-0
#
#                    28        29       30      31            32      33  \
# id
# 2   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 7   weather_related-1  floods-0  storm-1  fire-0  earthquake-0  cold-0
# 8   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 9   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 12  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
#
#                  34               35
# id
# 2   other_weather-0  direct_report-0
# 7   other_weather-0  direct_report-0
# 8   other_weather-0  direct_report-0
# 9   other_weather-0  direct_report-0
# 12  other_weather-0  direct_report-0
#
# [5 rows x 36 columns]

# %%
# select the first row of the categories dataframe
row = categories.iloc[0]

# use this row to extract a list of new column names for categories.
# one way is to apply a lambda function that takes everything 
# up to the second to last character of each string with slicing
category_colnames = [x.split("-")[0] for x in categories.iloc[0].tolist()]
print(category_colnames)
# Out:
# ['related', 'request', 'offer', 'aid_related', 'medical_help', 'medical_products', 'search_and_rescue', 'security', 'military', 'child_alone', 'water', 'food', 'shelter', 'clothing', 'money', 'missing_people', 'refugees', 'death', 'other_aid', 'infrastructure_related', 'transport', 'buildings', 'electricity', 'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure', 'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold', 'other_weather', 'direct_report']

# %%
# rename the columns of `categories`
categories.columns = category_colnames
categories.head()
# Out:
#       related    request    offer    aid_related    medical_help  \
# id
# 2   related-1  request-0  offer-0  aid_related-0  medical_help-0
# 7   related-1  request-0  offer-0  aid_related-1  medical_help-0
# 8   related-1  request-0  offer-0  aid_related-0  medical_help-0
# 9   related-1  request-1  offer-0  aid_related-1  medical_help-0
# 12  related-1  request-0  offer-0  aid_related-0  medical_help-0
#
#       medical_products    search_and_rescue    security    military  \
# id
# 2   medical_products-0  search_and_rescue-0  security-0  military-0
# 7   medical_products-0  search_and_rescue-0  security-0  military-0
# 8   medical_products-0  search_and_rescue-0  security-0  military-0
# 9   medical_products-1  search_and_rescue-0  security-0  military-0
# 12  medical_products-0  search_and_rescue-0  security-0  military-0
#
#       child_alone       ...           aid_centers    other_infrastructure  \
# id                      ...
# 2   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 7   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 8   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 9   child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 12  child_alone-0       ...         aid_centers-0  other_infrastructure-0
#
#       weather_related    floods    storm    fire    earthquake    cold  \
# id
# 2   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 7   weather_related-1  floods-0  storm-1  fire-0  earthquake-0  cold-0
# 8   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 9   weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 12  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
#
#       other_weather    direct_report
# id
# 2   other_weather-0  direct_report-0
# 7   other_weather-0  direct_report-0
# 8   other_weather-0  direct_report-0
# 9   other_weather-0  direct_report-0
# 12  other_weather-0  direct_report-0
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 4. Convert category values to just numbers 0 or 1.
# - Iterate through the category columns in df to keep only the last character of each string (the 1 or 0). For example, `related-0` becomes `0`, `related-1` becomes `1`. Convert the string to a numeric value.
# - You can perform [normal string actions on Pandas Series](https://pandas.pydata.org/pandas-docs/stable/text.html#indexing-with-str), like indexing, by including `.str` after the Series. You may need to first convert the Series to be of type string, which you can do with `astype(str)`.

# %%
categories
# Out:
#          related    request    offer    aid_related    medical_help  \
# id
# 2      related-1  request-0  offer-0  aid_related-0  medical_help-0
# 7      related-1  request-0  offer-0  aid_related-1  medical_help-0
# 8      related-1  request-0  offer-0  aid_related-0  medical_help-0
# 9      related-1  request-1  offer-0  aid_related-1  medical_help-0
# 12     related-1  request-0  offer-0  aid_related-0  medical_help-0
# 14     related-0  request-0  offer-0  aid_related-0  medical_help-0
# 15     related-1  request-0  offer-0  aid_related-0  medical_help-0
# 16     related-1  request-1  offer-0  aid_related-1  medical_help-0
# 17     related-0  request-0  offer-0  aid_related-0  medical_help-0
# 18     related-1  request-1  offer-0  aid_related-1  medical_help-1
# 20     related-1  request-1  offer-0  aid_related-1  medical_help-1
# 21     related-0  request-0  offer-0  aid_related-0  medical_help-0
# 22     related-1  request-1  offer-0  aid_related-1  medical_help-0
# 24     related-1  request-1  offer-0  aid_related-1  medical_help-0
# 25     related-1  request-0  offer-0  aid_related-0  medical_help-0
# 26     related-1  request-1  offer-0  aid_related-1  medical_help-0
# 27     related-1  request-1  offer-0  aid_related-1  medical_help-1
# 28     related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30     related-0  request-0  offer-0  aid_related-0  medical_help-0
# 31     related-1  request-0  offer-0  aid_related-0  medical_help-0
# 32     related-1  request-0  offer-0  aid_related-0  medical_help-0
# 33     related-1  request-1  offer-0  aid_related-1  medical_help-0
# 34     related-1  request-1  offer-0  aid_related-1  medical_help-0
# 35     related-1  request-1  offer-0  aid_related-1  medical_help-0
# 36     related-1  request-0  offer-0  aid_related-0  medical_help-0
# 37     related-0  request-0  offer-0  aid_related-0  medical_help-0
# 38     related-1  request-1  offer-0  aid_related-1  medical_help-1
# 39     related-1  request-1  offer-0  aid_related-1  medical_help-1
# 41     related-1  request-1  offer-0  aid_related-1  medical_help-0
# 42     related-1  request-1  offer-0  aid_related-1  medical_help-0
# ...          ...        ...      ...            ...             ...
# 30233  related-1  request-0  offer-0  aid_related-1  medical_help-1
# 30234  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30235  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30236  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30237  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30238  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30239  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30240  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30241  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30242  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30243  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30245  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30246  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30247  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30248  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30249  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30250  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30251  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30253  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30254  related-1  request-0  offer-0  aid_related-1  medical_help-1
# 30255  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30256  related-1  request-1  offer-0  aid_related-0  medical_help-0
# 30257  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30258  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30259  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30261  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30262  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30263  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30264  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30265  related-1  request-0  offer-0  aid_related-0  medical_help-0
#
#          medical_products    search_and_rescue    security    military  \
# id
# 2      medical_products-0  search_and_rescue-0  security-0  military-0
# 7      medical_products-0  search_and_rescue-0  security-0  military-0
# 8      medical_products-0  search_and_rescue-0  security-0  military-0
# 9      medical_products-1  search_and_rescue-0  security-0  military-0
# 12     medical_products-0  search_and_rescue-0  security-0  military-0
# 14     medical_products-0  search_and_rescue-0  security-0  military-0
# 15     medical_products-0  search_and_rescue-0  security-0  military-0
# 16     medical_products-0  search_and_rescue-0  security-0  military-0
# 17     medical_products-0  search_and_rescue-0  security-0  military-0
# 18     medical_products-1  search_and_rescue-0  security-0  military-0
# 20     medical_products-1  search_and_rescue-0  security-0  military-0
# 21     medical_products-0  search_and_rescue-0  security-0  military-0
# 22     medical_products-0  search_and_rescue-0  security-0  military-0
# 24     medical_products-0  search_and_rescue-0  security-0  military-0
# 25     medical_products-0  search_and_rescue-0  security-0  military-0
# 26     medical_products-1  search_and_rescue-0  security-0  military-0
# 27     medical_products-0  search_and_rescue-0  security-0  military-0
# 28     medical_products-0  search_and_rescue-0  security-0  military-0
# 30     medical_products-0  search_and_rescue-0  security-0  military-0
# 31     medical_products-0  search_and_rescue-0  security-0  military-0
# 32     medical_products-0  search_and_rescue-0  security-0  military-0
# 33     medical_products-0  search_and_rescue-0  security-0  military-0
# 34     medical_products-0  search_and_rescue-0  security-0  military-0
# 35     medical_products-0  search_and_rescue-0  security-0  military-0
# 36     medical_products-0  search_and_rescue-0  security-0  military-0
# 37     medical_products-0  search_and_rescue-0  security-0  military-0
# 38     medical_products-1  search_and_rescue-0  security-0  military-0
# 39     medical_products-0  search_and_rescue-0  security-0  military-0
# 41     medical_products-0  search_and_rescue-0  security-0  military-0
# 42     medical_products-0  search_and_rescue-0  security-0  military-0
# ...                   ...                  ...         ...         ...
# 30233  medical_products-0  search_and_rescue-0  security-0  military-0
# 30234  medical_products-1  search_and_rescue-0  security-0  military-0
# 30235  medical_products-0  search_and_rescue-0  security-0  military-0
# 30236  medical_products-0  search_and_rescue-0  security-0  military-0
# 30237  medical_products-0  search_and_rescue-0  security-0  military-0
# 30238  medical_products-0  search_and_rescue-0  security-0  military-1
# 30239  medical_products-0  search_and_rescue-0  security-0  military-0
# 30240  medical_products-0  search_and_rescue-0  security-0  military-1
# 30241  medical_products-0  search_and_rescue-0  security-0  military-0
# 30242  medical_products-0  search_and_rescue-0  security-0  military-0
# 30243  medical_products-0  search_and_rescue-0  security-0  military-0
# 30245  medical_products-0  search_and_rescue-1  security-0  military-0
# 30246  medical_products-1  search_and_rescue-0  security-0  military-0
# 30247  medical_products-0  search_and_rescue-0  security-0  military-0
# 30248  medical_products-0  search_and_rescue-0  security-0  military-0
# 30249  medical_products-0  search_and_rescue-0  security-0  military-0
# 30250  medical_products-0  search_and_rescue-0  security-0  military-0
# 30251  medical_products-0  search_and_rescue-0  security-0  military-0
# 30253  medical_products-0  search_and_rescue-0  security-0  military-0
# 30254  medical_products-1  search_and_rescue-0  security-0  military-0
# 30255  medical_products-0  search_and_rescue-0  security-0  military-0
# 30256  medical_products-0  search_and_rescue-0  security-0  military-0
# 30257  medical_products-0  search_and_rescue-0  security-0  military-0
# 30258  medical_products-0  search_and_rescue-0  security-0  military-0
# 30259  medical_products-0  search_and_rescue-0  security-0  military-0
# 30261  medical_products-0  search_and_rescue-0  security-0  military-0
# 30262  medical_products-0  search_and_rescue-0  security-0  military-0
# 30263  medical_products-0  search_and_rescue-0  security-0  military-0
# 30264  medical_products-0  search_and_rescue-0  security-0  military-1
# 30265  medical_products-0  search_and_rescue-0  security-0  military-0
#
#          child_alone       ...           aid_centers    other_infrastructure  \
# id                         ...
# 2      child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 7      child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 8      child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 9      child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 12     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 14     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 15     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 16     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 17     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 18     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 20     child_alone-0       ...         aid_centers-0  other_infrastructure-1
# 21     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 22     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 24     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 25     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 26     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 27     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 28     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 31     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 32     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 33     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 34     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 35     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 36     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 37     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 38     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 39     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 41     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 42     child_alone-0       ...         aid_centers-0  other_infrastructure-0
# ...              ...       ...                   ...                     ...
# 30233  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30234  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30235  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30236  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30237  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30238  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30239  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30240  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30241  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30242  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30243  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30245  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30246  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30247  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30248  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30249  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30250  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30251  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30253  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30254  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30255  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30256  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30257  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30258  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30259  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30261  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30262  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30263  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30264  child_alone-0       ...         aid_centers-0  other_infrastructure-0
# 30265  child_alone-0       ...         aid_centers-0  other_infrastructure-0
#
#          weather_related    floods    storm    fire    earthquake    cold  \
# id
# 2      weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 7      weather_related-1  floods-0  storm-1  fire-0  earthquake-0  cold-0
# 8      weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 9      weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 12     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 14     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 15     weather_related-1  floods-0  storm-1  fire-0  earthquake-0  cold-0
# 16     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 17     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 18     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 20     weather_related-1  floods-1  storm-0  fire-0  earthquake-0  cold-0
# 21     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 22     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 24     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 25     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 26     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 27     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 28     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 31     weather_related-1  floods-0  storm-0  fire-0  earthquake-1  cold-0
# 32     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 33     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 34     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 35     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 36     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 37     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 38     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 39     weather_related-1  floods-1  storm-0  fire-0  earthquake-0  cold-0
# 41     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 42     weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# ...                  ...       ...      ...     ...           ...     ...
# 30233  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30234  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30235  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30236  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30237  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30238  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30239  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30240  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30241  weather_related-1  floods-1  storm-0  fire-1  earthquake-0  cold-0
# 30242  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30243  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30245  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30246  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30247  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30248  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30249  weather_related-1  floods-1  storm-0  fire-0  earthquake-0  cold-0
# 30250  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30251  weather_related-1  floods-1  storm-0  fire-0  earthquake-0  cold-0
# 30253  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30254  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30255  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30256  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30257  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30258  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30259  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30261  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30262  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30263  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30264  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30265  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
#
#          other_weather    direct_report
# id
# 2      other_weather-0  direct_report-0
# 7      other_weather-0  direct_report-0
# 8      other_weather-0  direct_report-0
# 9      other_weather-0  direct_report-0
# 12     other_weather-0  direct_report-0
# 14     other_weather-0  direct_report-0
# 15     other_weather-0  direct_report-0
# 16     other_weather-0  direct_report-1
# 17     other_weather-0  direct_report-0
# 18     other_weather-0  direct_report-1
# 20     other_weather-0  direct_report-1
# 21     other_weather-0  direct_report-0
# 22     other_weather-0  direct_report-1
# 24     other_weather-0  direct_report-1
# 25     other_weather-0  direct_report-0
# 26     other_weather-0  direct_report-1
# 27     other_weather-0  direct_report-1
# 28     other_weather-0  direct_report-0
# 30     other_weather-0  direct_report-0
# 31     other_weather-0  direct_report-0
# 32     other_weather-0  direct_report-0
# 33     other_weather-0  direct_report-1
# 34     other_weather-0  direct_report-1
# 35     other_weather-0  direct_report-0
# 36     other_weather-0  direct_report-0
# 37     other_weather-0  direct_report-0
# 38     other_weather-0  direct_report-1
# 39     other_weather-0  direct_report-1
# 41     other_weather-0  direct_report-1
# 42     other_weather-0  direct_report-1
# ...                ...              ...
# 30233  other_weather-0  direct_report-0
# 30234  other_weather-0  direct_report-0
# 30235  other_weather-0  direct_report-0
# 30236  other_weather-0  direct_report-0
# 30237  other_weather-0  direct_report-0
# 30238  other_weather-0  direct_report-0
# 30239  other_weather-0  direct_report-0
# 30240  other_weather-0  direct_report-0
# 30241  other_weather-1  direct_report-0
# 30242  other_weather-0  direct_report-0
# 30243  other_weather-0  direct_report-0
# 30245  other_weather-0  direct_report-1
# 30246  other_weather-0  direct_report-1
# 30247  other_weather-0  direct_report-0
# 30248  other_weather-0  direct_report-0
# 30249  other_weather-0  direct_report-0
# 30250  other_weather-0  direct_report-0
# 30251  other_weather-0  direct_report-0
# 30253  other_weather-0  direct_report-0
# 30254  other_weather-0  direct_report-0
# 30255  other_weather-0  direct_report-0
# 30256  other_weather-0  direct_report-1
# 30257  other_weather-0  direct_report-0
# 30258  other_weather-0  direct_report-0
# 30259  other_weather-0  direct_report-0
# 30261  other_weather-0  direct_report-0
# 30262  other_weather-0  direct_report-0
# 30263  other_weather-0  direct_report-0
# 30264  other_weather-0  direct_report-0
# 30265  other_weather-0  direct_report-0
#
# [26386 rows x 36 columns]

# %%
for column in categories:
#     print(categories[column])
#     set each value to be the last character of the string
    try:
        categories[column] = [x[1] for x in categories[column].str.split("-")]
    except:
        print("something went wrong please try again")
        continue
    
    # convert column from string to numeric
    categories[column] = pd.to_numeric(categories[column])

# %%
categories.head()
# Out:
#     related  request  offer  aid_related  medical_help  medical_products  \
# id
# 2         1        0      0            0             0                 0
# 7         1        0      0            1             0                 0
# 8         1        0      0            0             0                 0
# 9         1        1      0            1             0                 1
# 12        1        0      0            0             0                 0
#
#     search_and_rescue  security  military  child_alone      ...        \
# id                                                          ...
# 2                   0         0         0            0      ...
# 7                   0         0         0            0      ...
# 8                   0         0         0            0      ...
# 9                   0         0         0            0      ...
# 12                  0         0         0            0      ...
#
#     aid_centers  other_infrastructure  weather_related  floods  storm  fire  \
# id
# 2             0                     0                0       0      0     0
# 7             0                     0                1       0      1     0
# 8             0                     0                0       0      0     0
# 9             0                     0                0       0      0     0
# 12            0                     0                0       0      0     0
#
#     earthquake  cold  other_weather  direct_report
# id
# 2            0     0              0              0
# 7            0     0              0              0
# 8            0     0              0              0
# 9            0     0              0              0
# 12           0     0              0              0
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 5. Replace `categories` column in `df` with new category columns.
# - Drop the categories column from the df dataframe since it is no longer needed.
# - Concatenate df and categories data frames.

# %%
# drop the original categories column from `df`
df = df.drop(columns=["categories"])

df.head()

# %%
# concatenate the original dataframe with the new `categories` dataframe
df = pd.DataFrame.join(self=df, other=categories)
df.head()

# %% [markdown]
# ### 6. Remove duplicates.
# - Check how many duplicates are in this dataset.
# - Drop the duplicates.
# - Confirm duplicates were removed.

# %%
len(df)
# Out:
# 27250

# %%
df.duplicated().sum()
# Out:
# 1035

# %%
# check number of duplicates
df.duplicated().sum()
# Out:
# 1035

# %%
# drop duplicates
df = df.drop_duplicates()

# %%
# check number of duplicates
assert df.duplicated().sum() == 0

# %% [markdown]
# ### 7. Save the clean dataset into an sqlite database.
# You can do this with pandas [`to_sql` method](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html) combined with the SQLAlchemy library. Remember to import SQLAlchemy's `create_engine` in the first cell of this notebook to use it below.

# %%
engine = create_engine('sqlite:///InsertDatabaseName.db')
df.to_sql('desaster_response', engine, index=False)

# %% [markdown]
# ### 8. Use this notebook to complete `etl_pipeline.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database based on new datasets specified by the user. Alternatively, you can complete `etl_pipeline.py` in the classroom on the `Project Workspace IDE` coming later.
